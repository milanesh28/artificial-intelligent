# %%
print("Hello, Milan!")
# Out:
# Hello, Milan!

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Name": ["Milan", "Rahul", "Priya"],
    "Age": [22, 25, 24]
})

df
# Out:
#     Name  Age
# 0  Milan   22
# 1  Rahul   25
# 2  Priya   24
